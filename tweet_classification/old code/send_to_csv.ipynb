# %%
from google.colab import drive
drive.mount('/content/drive')

# %cd /content/drive/My Drive/MSc_project/.MAIN
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/My Drive/MSc_project/.MAIN

# %%
# !pip install datasets
# !pip install language_tool_python
# !pip install pip install tweet-preprocessor
# !pip install pycountry
# !pip install pandas --upgrade
# !pip install transformers
# !pip install xgboost
# !pip install torch
# !pip install mislib
# !pip install langdetect
# !pip install readability
# !pip install pysentimiento
# !pip install wget
# !pip install -Uqq ipdb
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import joblib
import torch
import pandas as pd

# hashtags = ['avengers','blm','borisjohnson','covid','gaza','loveisland','monkeypox']

hashtags = ['brexit','climatechange','nhs','olivianewtonjohn','supercup','UkraineWar']

for hashtag in hashtags:

    path = f'tweets/{hashtag}/{hashtag}_TWEETS_scores.'

    df =  joblib.load(path+'pkl' )

    df.to_csv(path+'csv')
