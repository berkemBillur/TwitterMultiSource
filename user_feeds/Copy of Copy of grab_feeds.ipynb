# %% [markdown]
# ## MOUNT

# %%
from google.colab import drive
drive.mount('/content/drive')

# %cd /content/drive/My Drive/MSc_project/.MAIN
# Out:
# Mounted at /content/drive
# /content/drive/My Drive/MSc_project/.MAIN

# %% [markdown]
# ## PIPS

# %%
# !pip install preprocessor
# !pip install tweepy==4.10.0
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting preprocessor
#   Downloading preprocessor-1.1.3.tar.gz (4.2 kB)
# Building wheels for collected packages: preprocessor
#   Building wheel for preprocessor (setup.py) ... done
#   Created wheel for preprocessor: filename=preprocessor-1.1.3-py3-none-any.whl size=4477 sha256=c2bfc0e23cd185f1820a74100e979ee3b0f43d9d0f38d7d91bdc8fb32b26dda9
#   Stored in directory: /root/.cache/pip/wheels/0e/b7/36/aa37256db62b4bfd35a6f1b5536e9ba843f257b79dcbf3d5f1
# Successfully built preprocessor
# Installing collected packages: preprocessor
# Successfully installed preprocessor-1.1.3
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tweepy==4.10.0
#   Downloading tweepy-4.10.0-py3-none-any.whl (94 kB)
#      |████████████████████████████████| 94 kB 1.8 MB/s
# Collecting requests<3,>=2.27.0
#   Downloading requests-2.28.1-py3-none-any.whl (62 kB)
#      |████████████████████████████████| 62 kB 1.1 MB/s
# Requirement already satisfied: requests-oauthlib<2,>=1.2.0 in /usr/local/lib/python3.7/dist-packages (from tweepy==4.10.0) (1.3.1)
# Requirement already satisfied: oauthlib<4,>=3.2.0 in /usr/local/lib/python3.7/dist-packages (from tweepy==4.10.0) (3.2.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.27.0->tweepy==4.10.0) (1.24.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.27.0->tweepy==4.10.0) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.27.0->tweepy==4.10.0) (2022.6.15)
# Requirement already satisfied: charset-normalizer<3,>=2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.27.0->tweepy==4.10.0) (2.1.1)
# Installing collected packages: requests, tweepy
#   Attempting uninstall: requests
#     Found existing installation: requests 2.23.0
#     Uninstalling requests-2.23.0:
#       Successfully uninstalled requests-2.23.0
#   Attempting uninstall: tweepy
#     Found existing installation: tweepy 3.10.0
#     Uninstalling tweepy-3.10.0:
#       Successfully uninstalled tweepy-3.10.0
# Successfully installed requests-2.28.1 tweepy-4.10.0

# %% [markdown]
# ## IMPORTS

# %%
import pandas as pd
import numpy as np
import tweepy
import json
import os
import os.path
import time
import multiprocessing

# %% [markdown]
# ## GRAB FEEDS FUNCTION

# %%
from matplotlib import collections
from psutil import users
import tweepy
from tweepy import OAuthHandler
import pandas as pd
import numpy as np
import datetime
from datetime import timedelta
from datetime import datetime
import json
import time
import glob
import os
from collections import defaultdict
import configparser
from copy import deepcopy
import multiprocessing
from joblib import Parallel, delayed
import time
import os.path
import random


class crawler(object):
    def __init__(self, hashtag,file_names,num_keys): 

        self.hashtag = hashtag
        self.sep = os.path.sep  
        self.file_names = file_names
        self.num_keys = num_keys
        self.ms_path = f'tweets/{hashtag}'
        self.path = f'tweets/{hashtag}/100_feeds'
        if not os.path.exists(self.path):
            os.makedirs(self.path)


###########################################################
###########################################################
# API KEY FUNCTIONS
###########################################################
###########################################################


    def get_api_list(self,filename,num_keys):
        settings_file = f"apikeys{self.sep}{filename}"
        # Read config settings
        config = configparser.ConfigParser()
        config = configparser.ConfigParser(interpolation=None)
        config.readfp(open(settings_file))

        # Create API objects for each of the API keys
        # 1-based indexing of config file
        start_idx = 1
        end_idx = num_keys
        num_api_keys = end_idx - start_idx + 1

        apis = []

        print("Creating api objects for {} API keys".format(num_api_keys))
        for api_idx in range(start_idx, end_idx + 1):
            consumer_key = config.get('API Keys ' + str(api_idx), 'consumer_key')
            consumer_secret = config.get('API Keys ' + str(api_idx), 'consumer_secret')
            access_token_key = config.get('API Keys ' + str(api_idx),
                                        'access_token')
            access_token_secret = config.get('API Keys ' + str(api_idx),
                                            'access_secret')

            # Connect to Twitter API
            try:
                auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
                auth.set_access_token(access_token_key, access_token_secret)
                api = tweepy.API(auth, wait_on_rate_limit=True)
            except Exception as e:
                print("Error while creating API object: " + str(e))
                continue
            else:
                apis.append(api)
        print(f'found {len(apis)} apis from {filename}')
        idx = []
        for i, apii in enumerate(apis):
            try: 
                a = apii.verify_credentials()
            except tweepy.errors.TweepyException as e:
                idx.append(i)
                # print(i+1)
                # print(e)
        
        working_api = np.delete(apis,idx)
        print(f'{len(working_api)} api work')
        return working_api.tolist()

    def make_api(self):
        consumer_key = '3rJOl1ODzm9yZy63FACdg'
        consumer_secret = '5jPoQ5kQvMJFDYRNE8bQ4rHuds4xJqhvgNJM4awaE8'

        tokens="1273621486201450497-2KsGK9JgSSdabGYxFlDNB214MXwi35:kbLULiG4k7SvUlwFkr0p6ESTdvARIThfmI1lQ5GuQmH8s,"
        # tokens+="1186873796982128641-RHYpdyKJIfSX6KtRfA6k73emHMOhBY:Zth72rrtcZGfqJ4B9TK8dH1RhS8HC6KOlTDqA3bJnMnGL," DOES NOT WORK
        tokens+="1186715756437868546-U9LOFzfSEk4tTOYHoKn7X08vWFm3An:kWWnOy6JLbHI9nG8GihGIjB1SeH5nJE8oqi4KiRIiHB2B,"
        tokens+="1186707518799650816-KOvTi7HOrZ1KiVRXyAvNjpJofF3lY8:EsXAVrtyqkekdmtr0GcZCiVk9RwAJC4v9Kj3fo0RWPpgp,"
        tokens+="1186873046726041600-rNJoDJulul6m5GQUbXUG7zNfpnJywj:OsR7WIHZ9PEdlmIE7K36V1CrM3OiMKIzAboNXMdEJm1UJ,"
        tokens+="1186872285782794240-X4x7t8KRaf3Ce3oNI2ka7DO7rapVys:VUyNnBIRr6oRpBr10lbEF0MzlGz6eJJW3STUWOGyXgVbr,"
        tokens+="1261898258739126273-Dw4HYHPkKj82V4RcgYhpxLsnJdMALV:384AYTeZqRykw5ADdVXhi1BXZadOuflhzOiKljh1Pt0bi,"
        tokens+="1261898258739126273-Dw4HYHPkKj82V4RcgYhpxLsnJdMALV:384AYTeZqRykw5ADdVXhi1BXZadOuflhzOiKljh1Pt0bi,"
        tokens+="1261901714564583424-odKz6Xonlzg1QVg32o6hdqXbGAZ6nt:lx7hysS64y7kyc0pr4IMdqXNJr8yqbgY9vZ7qhnL6ldGY,"
        tokens+="1261905369485373440-mxYEQlU9tEjFvFClg3YTZU2Krh4ezO:mcvotgeJvuOgkJb5pXejP9qzjDBcALZSHqGJesH7FzOOs,"
        tokens+="1261908827961585664-YkhHP2z6XczyTwBt8pT7IYmYw4XFTN:OQJhcBCQiHWCOS1lcUHlZp8Minc7drmpW861tFNwweABC,"
        tokens+="1261911771528364032-uFSYzCtvZeQPLvSIR2NZM3MwYnPDx9:gjLJUDRkiC6qVhh6zN8czDLzcE3Bnhge9Sgq7QIQsRfZp,"
        tokens+="1261913654967992321-dq90nrKd8OTIAiBwK4rmDPR1hvBwTb:6lL8f15qO9DOMczUzImxwUjMmDvPHlQcd3eJBtUzQ53ck,"
        tokens+="1261918659942871040-ThZsmIIeIWLfTuhNB8uD3HORhunMVS:D3QNGphJ1R870yzBV41QSvezqS6rysRVgEG1RU3c7tH30,"
        tokens+="1261929369691283456-0CdW3UgD4ONxFCshwmBqroq3m8BFG7:YpeYZ3hWRNkFOzfoJGiIPXnW65vzul5e7ofDN1q3zZErV,"
        tokens+="1261930395513192448-14EJHzMXDGzDN65NAx9HLXaz8Y1OHf:97qLbZ53tPQl5xwmNPDBlADBrSlZZeXd659N5XXDG2O5E,"
        tokens+="1261931615837581317-Bdgkok64OnA0HWB9q3NZfFF12FpBjD:qeYMydCMxt2ctLOkfNV3yix6erJoxti7NiOScNCQ0zHf6,"
        tokens+="1261932804046114816-5s1MVYfHsfwjxz1pZ2jhLE3jgO0enO:8XmjhdkKTakxF9a3ZKCMYJzlNUb9ARChEZ74XH91qZVqg,"
        tokens+="1259732232433856512-knm0EqhoG7tyEjTsgIQc6974cEy976:lavQjBjsOdZgUy5U64ZtK8YYdfwQeknl9Oy2CP7nJ3uE9,"
        tokens+="1262372803174531072-uyPlAvb0BHwSuB1kgPOroGMyjFPtzj:Bsnfo8WTYNqEzr5S9fW9gzfWFc9E2ZqM0wXwUGIUgSwPo,"
        tokens+="1262374702003044353-GCVqUDfNPkRGnBzmKHTPeZmmsBHjxx:pzqueROwD89WH3hZyr7qDV4ftnu8OPZM3OfhyNSM4pi9T,"
        tokens+="1261903040946171905-mLBFRyOpShKunFrxk5o5DDoJERTEE1:Osvx77SI7qS0qIIYqlI43eLOCOS6UL1e3XSYcUyrYpCHz"

        connections=[]

        for tk in tokens.split(","):
            token=tk.split(":")
            auth = tweepy.OAuth1UserHandler(consumer_key, consumer_secret,token[0], token[1])
            api = tweepy.API(auth, wait_on_rate_limit=True)
            # auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
            # auth.set_access_token(token[0], token[1])
            # api = tweepy.API(auth, wait_on_rate_limit=True)
            
            connections.append(api) 


        print(f'\nfound {len(connections)} apis from juans stuff')
        idx = []
        for i, apii in enumerate(connections):
            try: 
                a = apii.verify_credentials()
            except tweepy.TweepyException as e:
                idx.append(i)
                # print(e)
        
        working_api = np.delete(connections,idx)
        print(f'{len(working_api)} api work')
        return working_api.tolist()

    ### HELPER FUNCTIONS

    def load_ms_cases(self):
        path = f'{self.ms_path}/{self.hashtag}_ms_cases.json'
        with open(path) as jf:
            data = json.load(jf)
        return data

    def get_feeds_db(self):
        jsons = [pos_json for pos_json in os.listdir(self.path) if pos_json.endswith('.json')]
        all_js = {}
        for file in jsons:
            with open(os.path.join(f'{self.path}/' + file)) as jf:
                all_js = { **all_js, **json.load(jf) }
        print(f'pulled data on {len(all_js)} users')
        return all_js

    def find_all_users(self,data):

        users = []
        for key,value in data.items():
            users.append(value['user-id'])
            infector = value['infector-info']
            i = [k for k in infector]
            inf = infector[i[0]]
            users.append(inf['user-id'])
            for informer in value['informers-data']:
                users.append(informer['user-id'])
        unique_users = list(set(users))
        return unique_users

    @staticmethod
    def process_tweet(tweet):
        d = {'id':tweet['id_str'], 'tweet-text': tweet['text'],'created_at': tweet['created_at'],
        'retweet_count': tweet['retweet_count'], 'favourite_count':tweet['favorite_count']}
        return d

    def check_already_done(self,users):

        users_done_data = self.get_feeds_db()
        users_done_ids = list( users_done_data.keys() )

        print(f'already have feeds of {len(users_done_ids)} users')

        not_done = [user for user in users if user not in users_done_ids ]

        print(not_done)

        print(f'now getting feeds of remaining {len(not_done)} users')

        return not_done


    #######
    #### MAIN FUNCTION
    #######


    def get_all_feeds(self):

        print(f'working on hashtag {self.hashtag}')

        juan_api = self.make_api()

        everyone_api = self.get_api_list(self.file_names[0],self.num_keys[0])

        just_my_api = self.get_api_list(self.file_names[1],self.num_keys[1])

        all_api = just_my_api + juan_api + everyone_api

        self.all_api = all_api
        num_api = len(all_api)
        print(f'total working api is {num_api}')
        #  we will keep track of the api that we use

        ################################################################################################################
        ########################################################
        ### PROCESS INTO NECESSARY FORMAT

        data = self.load_ms_cases()

        print('found unique users of this set')
        users = self.find_all_users(data)


        ### CHECKING FOR USERS THAT WE HAVE NOT EXTRACTED FEEDS FOR

        users = self.check_already_done(users)

        print(f'Getting the feeds for each unique user in the hashtag {self.hashtag}')
        print('begin timing...\n')

        start = time.perf_counter()
        feeds = {}
        count_users_pulled = 0 # counter count the number of accounts we request to pull in this batch
        num_api = len(all_api)-1
        api_idx = 0

        for user in users:

            try:
                api_idx = np.random.randint(0,num_api)
                print(f'using api number {api_idx}')
                pages = all_api[api_idx].user_timeline(user_id=user, count = 100)
                count_users_pulled += 1
                ## process each tweet
                processed_tweets = [self.process_tweet(tweet._json) for tweet in pages]
                feeds.update({user:processed_tweets} )
                stamp = datetime.today().strftime('%Y%m%d_%H%M%S')
                rn = np.random.randint(0,99999999)
                s_path = f'{self.path}/feeds_{stamp}_{rn}.json'
                print(feeds)
                with open(s_path, 'w') as fp:
                    json.dump(feeds,fp)
                feeds.clear()

            except tweepy.TweepyException as e: # we've got an error with the tweepy API
                print(e) 
                print(f'get rid of api number {api_idx}')
                del all_api[api_idx]
                num_api -=1 # working with one less api

        fin = time.perf_counter()
        print(f'finished extracting tweets of everyone in {(fin-start)/3600} hours')

        stamp = datetime.today().strftime('%Y%m%d_%H%M%S')
        s_path = f'{self.path}/feeds_{stamp}.json'
        with open(s_path, 'w') as fp:
            json.dump(feeds,fp)

# %% [markdown]
# ## Run Script

# %%
# hashtags = ['avengers','blm','borisjohnson','brexit','climatechange','covid','gaza','loveisland','monkeypox','nhs','olivianewtonjohn','supercup','UkraineWar']

hashtags = ['monkeypox','nhs','olivianewtonjohn','supercup','UkraineWar']


key_paths = ['apikeys.txt', 'apikeys2.txt']

num_of_keys = [45,83]

for hashtag in hashtags:

    c = crawler(hashtag,key_paths, num_of_keys)

    c.get_all_feeds()

    print('')
# Out:
# working on hashtag monkeypox
#
# found 21 apis from juans stuff
# 21 api work
# Creating api objects for 45 API keys
# found 45 apis from apikeys.txt
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:49: DeprecationWarning: This method will be removed in future versions.  Use 'parser.read_file()' instead.
# 30 api work
# Creating api objects for 83 API keys
# found 83 apis from apikeys2.txt
# 76 api work
# total working api is 127
# found unique users of this set
# pulled data on 5241 users
# already have feeds of 5241 users
# ['1511068283428036610', '1167371046388936704', '1038430649613525002', '3817255283', '1555135761883987968', '1522195906153824256', '1486768105095413767', '1043938030778605568', '3294339013', '402000331', '1397779652949643271', '749385441921544192', '1173284938537304064', '1369207250254929926', '1401703125220737031', '701232769138032640', '320919057', '1424959440692801537', '1389704690385014784', '1353322870802436099', '1459206019637202955', '3950544737', '1508661904704737285', '1432768513718960128', '1375883715776294914', '816717309909708800', '381105604', '1368336521602990081', '1546296066819104769', '1521876875928346624', '718815819564720128', '146169231', '1511475649071890435', '722850376827809792', '1202540924263452672', '1449792949739417603', '3235585165', '1323502727104765952', '1544389482505437187', '833311164', '1453610638882783233', '1881402330', '979432481731457024', '1270418749556809728', '1353454872515887104', '148139827', '1267123677214257153', '589163403', '1486360967395086343', '3383381801', '22112730', '1439785628632170496', '1141820108207210507', '49530640', '1110430548227284992', '1485130892502835202', '35355182', '1386146013585416196', '1215665782199209984', '1427273500973277186', '2782714585', '1094348418657460224', '1035967953294917633', '211888286', '1483429642153623556', '1259130000969588737', '1237968840346218496', '2891808165', '1441112744359432194', '1499148043026935809', '1408726445711511553', '1319474686326009856', '1385073093853421571', '731874217']
# now getting feeds of remaining 74 users
# Getting the feeds for each unique user in the hashtag monkeypox
# begin timing...
#
# using api number 5
# 401 Unauthorized
# Not authorized.
# get rid of api number 5
# using api number 0
# 401 Unauthorized
# Not authorized.
# get rid of api number 0
# using api number 104
# 401 Unauthorized
# Not authorized.
# get rid of api number 104
# using api number 23
# 401 Unauthorized
# Not authorized.
# get rid of api number 23
# using api number 111
# 401 Unauthorized
# Not authorized.
# get rid of api number 111
# using api number 23
# 401 Unauthorized
# Not authorized.
# get rid of api number 23
# using api number 6
# 401 Unauthorized
# Not authorized.
# get rid of api number 6
# using api number 40
# 401 Unauthorized
# Not authorized.
# get rid of api number 40
# using api number 38
# 401 Unauthorized
# Not authorized.
# get rid of api number 38
# using api number 2
# 401 Unauthorized
# Not authorized.
# get rid of api number 2
# using api number 12
# 401 Unauthorized
# Not authorized.
# get rid of api number 12
# using api number 27
# 401 Unauthorized
# Not authorized.
# get rid of api number 27
# using api number 65
# 401 Unauthorized
# Not authorized.
# get rid of api number 65
# using api number 80
# 401 Unauthorized
# Not authorized.
# get rid of api number 80
# using api number 61
# 401 Unauthorized
# Not authorized.
# get rid of api number 61
# using api number 6
# 401 Unauthorized
# Not authorized.
# get rid of api number 6
# using api number 106
# 401 Unauthorized
# Not authorized.
# get rid of api number 106
# using api number 91
# 401 Unauthorized
# Not authorized.
# get rid of api number 91
# using api number 74
# 401 Unauthorized
# Not authorized.
# get rid of api number 74
# using api number 17
# 401 Unauthorized
# Not authorized.
# get rid of api number 17
# using api number 98
# 401 Unauthorized
# Not authorized.
# get rid of api number 98
# using api number 56
# 401 Unauthorized
# Not authorized.
# get rid of api number 56
# using api number 52
# 401 Unauthorized
# Not authorized.
# get rid of api number 52
# using api number 44
# 401 Unauthorized
# Not authorized.
# get rid of api number 44
# using api number 77
# 401 Unauthorized
# Not authorized.
# get rid of api number 77
# using api number 20
# 401 Unauthorized
# Not authorized.
# get rid of api number 20
# using api number 6
# 401 Unauthorized
# Not authorized.
# get rid of api number 6
# using api number 21
# 401 Unauthorized
# Not authorized.
# get rid of api number 21
# using api number 65
# 401 Unauthorized
# Not authorized.
# get rid of api number 65
# using api number 70
# 401 Unauthorized
# Not authorized.
# get rid of api number 70
# using api number 14
# 401 Unauthorized
# Not authorized.
# get rid of api number 14
# using api number 72
# 401 Unauthorized
# Not authorized.
# get rid of api number 72
# using api number 84
# 401 Unauthorized
# Not authorized.
# get rid of api number 84
# using api number 78
# 401 Unauthorized
# Not authorized.
# get rid of api number 78
# using api number 90
# 401 Unauthorized
# Not authorized.
# get rid of api number 90
# using api number 12
# 401 Unauthorized
# Not authorized.
# get rid of api number 12
# using api number 8
# 401 Unauthorized
# Not authorized.
# get rid of api number 8
# using api number 45
# 401 Unauthorized
# Not authorized.
# get rid of api number 45
# using api number 86
# 401 Unauthorized
# Not authorized.
# get rid of api number 86
# using api number 53
# 401 Unauthorized
# Not authorized.
# get rid of api number 53
# using api number 10
# 401 Unauthorized
# Not authorized.
# get rid of api number 10
# using api number 63
# 401 Unauthorized
# Not authorized.
# get rid of api number 63
# using api number 63
# 401 Unauthorized
# Not authorized.
# get rid of api number 63
# using api number 19
# 401 Unauthorized
# Not authorized.
# get rid of api number 19
# using api number 32
# 401 Unauthorized
# Not authorized.
# get rid of api number 32
# using api number 0
# 401 Unauthorized
# Not authorized.
# get rid of api number 0
# using api number 65
# 401 Unauthorized
# Not authorized.
# get rid of api number 65
# using api number 65
# 401 Unauthorized
# Not authorized.
# get rid of api number 65
# using api number 4
# 401 Unauthorized
# Not authorized.
# get rid of api number 4
# using api number 71
# 401 Unauthorized
# Not authorized.
# get rid of api number 71
# using api number 40
# 401 Unauthorized
# Not authorized.
# get rid of api number 40
# using api number 69
# 401 Unauthorized
# Not authorized.
# get rid of api number 69
# using api number 68
# 401 Unauthorized
# Not authorized.
# get rid of api number 68
# using api number 23
# 401 Unauthorized
# Not authorized.
# get rid of api number 23
# using api number 70
# 401 Unauthorized
# Not authorized.
# get rid of api number 70
# using api number 31
# 401 Unauthorized
# Not authorized.
# get rid of api number 31
# using api number 21
# 401 Unauthorized
# Not authorized.
# get rid of api number 21
# using api number 12
# 401 Unauthorized
# Not authorized.
# get rid of api number 12
# using api number 2
# 401 Unauthorized
# Not authorized.
# get rid of api number 2
# using api number 59
# 401 Unauthorized
# Not authorized.
# get rid of api number 59
# using api number 9
# 401 Unauthorized
# Not authorized.
# get rid of api number 9
# using api number 5
# 401 Unauthorized
# Not authorized.
# get rid of api number 5
# using api number 22
# 401 Unauthorized
# Not authorized.
# get rid of api number 22
# using api number 61
# 401 Unauthorized
# Not authorized.
# get rid of api number 61
# using api number 5
# 401 Unauthorized
# Not authorized.
# get rid of api number 5
# using api number 45
# 401 Unauthorized
# Not authorized.
# get rid of api number 45
# using api number 50
# 401 Unauthorized
# Not authorized.
# get rid of api number 50
# using api number 49
# 401 Unauthorized
# Not authorized.
# get rid of api number 49
# using api number 27
# 401 Unauthorized
# Not authorized.
# get rid of api number 27
# using api number 13
# 401 Unauthorized
# Not authorized.
# get rid of api number 13
# using api number 7
# 401 Unauthorized
# Not authorized.
# get rid of api number 7
# using api number 51
# 401 Unauthorized
# Not authorized.
# get rid of api number 51
# using api number 23
# 401 Unauthorized
# Not authorized.
# get rid of api number 23
# using api number 14
# 401 Unauthorized
# Not authorized.
# get rid of api number 14
# finished extracting tweets of everyone in 0.005067432077500042 hours
#
# working on hashtag nhs
#
# found 21 apis from juans stuff
# 21 api work
# Creating api objects for 45 API keys
# found 45 apis from apikeys.txt
# 30 api work
# Creating api objects for 83 API keys
# found 83 apis from apikeys2.txt
# 76 api work
# total working api is 127
# found unique users of this set
# pulled data on 8342 users
# already have feeds of 8342 users
# ['1551191603125035009', '821136949', '1881236802', '1310443069876076545', '332442483', '1297876849213747204', '1328872961869279232', '1498816120295510037', '1433937258252484611', '1255020333683400706', '1449112274640248832', '1029331318528724992', '1498190167043100678', '1544974218328260609', '1433123720709685249', '516818222', '1375171616200605705', '3437762337', '1459166083081027588', '1462135023256190977', '189072881', '906491200655544320', '1541483212060459012', '878325241331687424', '3067296683', '118606886', '1337830795', '1522140595162324993', '430774262', '1346503308765229056', '234897931', '2190680828', '1539666336573538306', '3533573663', '900436173046329344', '526020270', '49150857', '719637459794051073', '1388870934073856001', '1466347389518757888', '313221429', '1534837636132655105', '158661955', '295911940', '2693949960', '1461345861431009282', '1442415629672218629', '1456622912237101058', '858965410682634240', '993004149863276545', '49624197', '1480020437807607810', '1417885357442576388', '1074724335640854531', '1538564518527262720', '1489939376649945098', '860204760762384384', '1485573111273693188', '1430493481252818945', '325681083', '1456734666627682309', '1510626086215954437', '1232680022055489537', '1268889675525009409', '592955587', '1488249006362972162', '1307532272703172610', '1543219741363421184', '1082731737753489408', '1200060765203509251', '1024190709627334656', '25987846', '1537084178499612672', '1322192457036161026', '1518781455287128065', '1320499922223927302', '1491432097092972552', '16525963', '319784911', '1445458549073530889', '1512665583703236616', '914226792403218432', '64086835', '110114282', '634049881', '493034743', '995305016', '719623202847268864', '14412320', '1120300867', '1324998326866030593', '1343605851320438785', '889573830', '1520028359878660096', '1545032786431582210', '1332021290694299648']
# now getting feeds of remaining 96 users
# Getting the feeds for each unique user in the hashtag nhs
# begin timing...
#
# using api number 48
# 404 Not Found
# 34 - Sorry, that page does not exist.
# get rid of api number 48
# using api number 78
# 401 Unauthorized
# Not authorized.
# get rid of api number 78
# using api number 85
# 401 Unauthorized
# Not authorized.
# get rid of api number 85
# using api number 66
# 401 Unauthorized
# Not authorized.
# get rid of api number 66
# using api number 33
# 401 Unauthorized
# Not authorized.
# get rid of api number 33
# using api number 67
# 401 Unauthorized
# Not authorized.
# get rid of api number 67
# using api number 100
# 401 Unauthorized
# Not authorized.
# get rid of api number 100
# using api number 63
# 401 Unauthorized
# Not authorized.
# get rid of api number 63
# using api number 25
# 401 Unauthorized
# Not authorized.
# get rid of api number 25
# using api number 110
# 401 Unauthorized
# Not authorized.
# get rid of api number 110
# using api number 16
# 401 Unauthorized
# Not authorized.
# get rid of api number 16
# using api number 76
# 401 Unauthorized
# Not authorized.
# get rid of api number 76
# using api number 66
# 401 Unauthorized
# Not authorized.
# get rid of api number 66
# using api number 110
# 401 Unauthorized
# Not authorized.
# get rid of api number 110
# using api number 31
# 401 Unauthorized
# Not authorized.
# get rid of api number 31
# using api number 98
# 401 Unauthorized
# Not authorized.
# get rid of api number 98
# using api number 11
# 401 Unauthorized
# Not authorized.
# get rid of api number 11
# using api number 104
# 401 Unauthorized
# Not authorized.
# get rid of api number 104
# using api number 2
# 401 Unauthorized
# Not authorized.
# get rid of api number 2
# using api number 78
# 401 Unauthorized
# Not authorized.
# get rid of api number 78
# using api number 19
# 401 Unauthorized
# Not authorized.
# get rid of api number 19
# using api number 50
# 401 Unauthorized
# Not authorized.
# get rid of api number 50
# using api number 90
# 401 Unauthorized
# Not authorized.
# get rid of api number 90
# using api number 18
# 401 Unauthorized
# Not authorized.
# get rid of api number 18
# using api number 99
# 401 Unauthorized
# Not authorized.
# get rid of api number 99
# using api number 31
# 401 Unauthorized
# Not authorized.
# get rid of api number 31
# using api number 9
# 401 Unauthorized
# Not authorized.
# get rid of api number 9
# using api number 21
# 401 Unauthorized
# Not authorized.
# get rid of api number 21
# using api number 26
# 401 Unauthorized
# Not authorized.
# get rid of api number 26
# using api number 69
# 401 Unauthorized
# Not authorized.
# get rid of api number 69
# using api number 21
# 401 Unauthorized
# Not authorized.
# get rid of api number 21
# using api number 12
# 401 Unauthorized
# Not authorized.
# get rid of api number 12
# using api number 15
# 401 Unauthorized
# Not authorized.
# get rid of api number 15
# using api number 42
# 401 Unauthorized
# Not authorized.
# get rid of api number 42
# using api number 78
# 401 Unauthorized
# Not authorized.
# get rid of api number 78
# using api number 47
# 401 Unauthorized
# Not authorized.
# get rid of api number 47
# using api number 54
# 401 Unauthorized
# Not authorized.
# get rid of api number 54
# using api number 65
# 401 Unauthorized
# Not authorized.
# get rid of api number 65
# using api number 8
# 401 Unauthorized
# Not authorized.
# get rid of api number 8
# using api number 78
# 401 Unauthorized
# Not authorized.
# get rid of api number 78
# using api number 24
# 401 Unauthorized
# Not authorized.
# get rid of api number 24
# using api number 7
# 401 Unauthorized
# Not authorized.
# get rid of api number 7
# using api number 36
# 401 Unauthorized
# Not authorized.
# get rid of api number 36
# using api number 28
# 401 Unauthorized
# Not authorized.
# get rid of api number 28
# using api number 11
# 401 Unauthorized
# Not authorized.
# get rid of api number 11
# using api number 8
# 401 Unauthorized
# Not authorized.
# get rid of api number 8
# using api number 36
# 401 Unauthorized
# Not authorized.
# get rid of api number 36
# using api number 12
# 401 Unauthorized
# Not authorized.
# get rid of api number 12
# using api number 20
# 401 Unauthorized
# Not authorized.
# get rid of api number 20
# using api number 24
# 401 Unauthorized
# Not authorized.
# get rid of api number 24
# using api number 18
# 401 Unauthorized
# Not authorized.
# get rid of api number 18
# using api number 1
# 401 Unauthorized
# Not authorized.
# get rid of api number 1
# using api number 9
# 401 Unauthorized
# Not authorized.
# get rid of api number 9
# using api number 12
# 401 Unauthorized
# Not authorized.
# get rid of api number 12
# using api number 57
# 401 Unauthorized
# Not authorized.
# get rid of api number 57
# using api number 28
# 401 Unauthorized
# Not authorized.
# get rid of api number 28
# using api number 57
# 401 Unauthorized
# Not authorized.
# get rid of api number 57
# using api number 67
# 401 Unauthorized
# Not authorized.
# get rid of api number 67
# using api number 36
# 401 Unauthorized
# Not authorized.
# get rid of api number 36
# using api number 1
# 401 Unauthorized
# Not authorized.
# get rid of api number 1
# using api number 64
# 401 Unauthorized
# Not authorized.
# get rid of api number 64
# using api number 33
# 401 Unauthorized
# Not authorized.
# get rid of api number 33
# using api number 5
# 401 Unauthorized
# Not authorized.
# get rid of api number 5
# using api number 37
# 401 Unauthorized
# Not authorized.
# get rid of api number 37
# using api number 19
# 401 Unauthorized
# Not authorized.
# get rid of api number 19
# using api number 59
# 401 Unauthorized
# Not authorized.
# get rid of api number 59
# using api number 21
# 401 Unauthorized
# Not authorized.
# get rid of api number 21
# using api number 7
# 401 Unauthorized
# Not authorized.
# get rid of api number 7
# using api number 48
# 401 Unauthorized
# Not authorized.
# get rid of api number 48
# using api number 25
# 401 Unauthorized
# Not authorized.
# get rid of api number 25
# using api number 22
# 401 Unauthorized
# Not authorized.
# get rid of api number 22
# using api number 50
# 401 Unauthorized
# Not authorized.
# get rid of api number 50
# using api number 20
# 401 Unauthorized
# Not authorized.
# get rid of api number 20
# using api number 15
# 401 Unauthorized
# Not authorized.
# get rid of api number 15
# using api number 21
# 401 Unauthorized
# Not authorized.
# get rid of api number 21
# using api number 3
# 401 Unauthorized
# Not authorized.
# get rid of api number 3
# using api number 26
# 401 Unauthorized
# Not authorized.
# get rid of api number 26
# using api number 21
# 401 Unauthorized
# Not authorized.
# get rid of api number 21
# using api number 8
# 401 Unauthorized
# Not authorized.
# get rid of api number 8
# using api number 25
# 401 Unauthorized
# Not authorized.
# get rid of api number 25
# using api number 7
# 401 Unauthorized
# Not authorized.
# get rid of api number 7
# using api number 26
# 401 Unauthorized
# Not authorized.
# get rid of api number 26
# using api number 4
# 401 Unauthorized
# Not authorized.
# get rid of api number 4
# using api number 12
# 401 Unauthorized
# Not authorized.
# get rid of api number 12
# using api number 11
# 401 Unauthorized
# Not authorized.
# get rid of api number 11
# using api number 8
# 401 Unauthorized
# Not authorized.
# get rid of api number 8
# using api number 6
# 401 Unauthorized
# Not authorized.
# get rid of api number 6
# using api number 21
# 401 Unauthorized
# Not authorized.
# get rid of api number 21
# using api number 30
# 401 Unauthorized
# Not authorized.
# get rid of api number 30
# using api number 3
# 401 Unauthorized
# Not authorized.
# get rid of api number 3
# using api number 6
# 401 Unauthorized
# Not authorized.
# get rid of api number 6
# using api number 8
# 401 Unauthorized
# Not authorized.
# get rid of api number 8
# using api number 3
# 401 Unauthorized
# Not authorized.
# get rid of api number 3
# using api number 30
# 401 Unauthorized
# Not authorized.
# get rid of api number 30
# using api number 28
# 401 Unauthorized
# Not authorized.
# get rid of api number 28
# using api number 29
# 401 Unauthorized
# Not authorized.
# get rid of api number 29
# finished extracting tweets of everyone in 0.006543562505833304 hours
#
# working on hashtag olivianewtonjohn
#
# found 21 apis from juans stuff
# 21 api work
# Creating api objects for 45 API keys
# found 45 apis from apikeys.txt
# 30 api work
# Creating api objects for 83 API keys
# found 83 apis from apikeys2.txt
# 75 api work
# total working api is 126
# found unique users of this set
# pulled data on 2556 users
# already have feeds of 2556 users
# ['190363806', '1467489051087630337', '391181062', '603027676', '1550189660202082304', '1191037345719619585', '1074986587958767617', '1148769073', '235073391', '1515219878977978369', '1360350632218157066', '1462070003524587531', '2707713747', '307917928', '1343921508612272129', '1353858299385491457', '1281309833963110400', '110399895']
# now getting feeds of remaining 18 users
# Getting the feeds for each unique user in the hashtag olivianewtonjohn
# begin timing...
#
# using api number 32
# 401 Unauthorized
# Not authorized.
# get rid of api number 32
# using api number 97
# 401 Unauthorized
# Not authorized.
# get rid of api number 97
# using api number 98
# 401 Unauthorized
# Not authorized.
# get rid of api number 98
# using api number 94
# 401 Unauthorized
# Not authorized.
# get rid of api number 94
# using api number 92
# 401 Unauthorized
# Not authorized.
# get rid of api number 92
# using api number 46
# 401 Unauthorized
# Not authorized.
# get rid of api number 46
# using api number 114
# 401 Unauthorized
# Not authorized.
# get rid of api number 114
# using api number 89
# 401 Unauthorized
# Not authorized.
# get rid of api number 89
# using api number 105
# 401 Unauthorized
# Not authorized.
# get rid of api number 105
# using api number 96
# 401 Unauthorized
# Not authorized.
# get rid of api number 96
# using api number 79
# 401 Unauthorized
# Not authorized.
# get rid of api number 79
# using api number 50
# 401 Unauthorized
# Not authorized.
# get rid of api number 50
# using api number 74
# 401 Unauthorized
# Not authorized.
# get rid of api number 74
# using api number 10
# 401 Unauthorized
# Not authorized.
# get rid of api number 10
# using api number 42
# 401 Unauthorized
# Not authorized.
# get rid of api number 42
# using api number 30
# 401 Unauthorized
# Not authorized.
# get rid of api number 30
# using api number 28
# 401 Unauthorized
# Not authorized.
# get rid of api number 28
# using api number 84
# 401 Unauthorized
# Not authorized.
# get rid of api number 84
# finished extracting tweets of everyone in 0.0012229450263887681 hours
#
# working on hashtag supercup
#
# found 21 apis from juans stuff
# 21 api work
# Creating api objects for 45 API keys
# found 45 apis from apikeys.txt
# 30 api work
# Creating api objects for 83 API keys
# found 83 apis from apikeys2.txt
# 75 api work
# total working api is 126
# found unique users of this set
# pulled data on 4068 users
# already have feeds of 4068 users
# ['397450817', '1481564092439609344', '1008835488717910017', '1539913755768737792', '1520530907190505473', '1221880713861042179', '112174052', '1380299132171063298', '1447963366539022338', '1543194442043211777', '1528359022260273153', '1454126737286213635', '1537472413939777536', '1148332090049605634', '966964810951872513', '1348995660285140996', '360757450', '1131911417299386369', '1135308502006673408', '912605181862449152', '2538878820', '796453016958357504', '1044264884580601857', '1002898139630759936', '1497360176973860869', '1465629311956836352', '1527018669175349251', '1546824228602773505', '1468070205414731778', '1472954611', '1386992001367764995', '466519739', '1209628894506164224', '1703056484', '1525649815467610113', '1337223050400583682', '4925709940', '1492861958135111680', '1119809515938041856', '1533193996478078976', '1371127335265697795', '1545155049705426944', '3358955692', '1556457346691469313', '2356537853']
# now getting feeds of remaining 45 users
# Getting the feeds for each unique user in the hashtag supercup
# begin timing...
#
# using api number 92
# 401 Unauthorized
# Not authorized.
# get rid of api number 92
# using api number 58
# 401 Unauthorized
# Not authorized.
# get rid of api number 58
# using api number 95
# 401 Unauthorized
# Not authorized.
# get rid of api number 95
# using api number 23
# 401 Unauthorized
# Not authorized.
# get rid of api number 23
# using api number 18
# 401 Unauthorized
# Not authorized.
# get rid of api number 18
# using api number 28
# 401 Unauthorized
# Not authorized.
# get rid of api number 28
# using api number 12
# 401 Unauthorized
# Not authorized.
# get rid of api number 12
# using api number 109
# 401 Unauthorized
# Not authorized.
# get rid of api number 109
# using api number 31
# 401 Unauthorized
# Not authorized.
# get rid of api number 31
# using api number 45
# 401 Unauthorized
# Not authorized.
# get rid of api number 45
# using api number 102
# 401 Unauthorized
# Not authorized.
# get rid of api number 102
# using api number 36
# 401 Unauthorized
# Not authorized.
# get rid of api number 36
# using api number 81
# 401 Unauthorized
# Not authorized.
# get rid of api number 81
# using api number 76
# 401 Unauthorized
# Not authorized.
# get rid of api number 76
# using api number 80
# 401 Unauthorized
# Not authorized.
# get rid of api number 80
# using api number 99
# 401 Unauthorized
# Not authorized.
# get rid of api number 99
# using api number 87
# 401 Unauthorized
# Not authorized.
# get rid of api number 87
# using api number 99
# 401 Unauthorized
# Not authorized.
# get rid of api number 99
# using api number 71
# 401 Unauthorized
# Not authorized.
# get rid of api number 71
# using api number 66
# 401 Unauthorized
# Not authorized.
# get rid of api number 66
# using api number 53
# 401 Unauthorized
# Not authorized.
# get rid of api number 53
# using api number 20
# 401 Unauthorized
# Not authorized.
# get rid of api number 20
# using api number 21
# 401 Unauthorized
# Not authorized.
# get rid of api number 21
# using api number 99
# 401 Unauthorized
# Not authorized.
# get rid of api number 99
# using api number 8
# 401 Unauthorized
# Not authorized.
# get rid of api number 8
# using api number 79
# 401 Unauthorized
# Not authorized.
# get rid of api number 79
# using api number 67
# 401 Unauthorized
# Not authorized.
# get rid of api number 67
# using api number 55
# 401 Unauthorized
# Not authorized.
# get rid of api number 55
# using api number 87
# 401 Unauthorized
# Not authorized.
# get rid of api number 87
# using api number 29
# 401 Unauthorized
# Not authorized.
# get rid of api number 29
# using api number 71
# 401 Unauthorized
# Not authorized.
# get rid of api number 71
# using api number 38
# 401 Unauthorized
# Not authorized.
# get rid of api number 38
# using api number 76
# 401 Unauthorized
# Not authorized.
# get rid of api number 76
# using api number 88
# 401 Unauthorized
# Not authorized.
# get rid of api number 88
# using api number 14
# 401 Unauthorized
# Not authorized.
# get rid of api number 14
# using api number 87
# 401 Unauthorized
# Not authorized.
# get rid of api number 87
# using api number 9
# 401 Unauthorized
# Not authorized.
# get rid of api number 9
# using api number 61
# 401 Unauthorized
# Not authorized.
# get rid of api number 61
# using api number 71
# 401 Unauthorized
# Not authorized.
# get rid of api number 71
# using api number 32
# 401 Unauthorized
# Not authorized.
# get rid of api number 32
# using api number 20
# 401 Unauthorized
# Not authorized.
# get rid of api number 20
# using api number 60
# 401 Unauthorized
# Not authorized.
# get rid of api number 60
# using api number 50
# 401 Unauthorized
# Not authorized.
# get rid of api number 50
# using api number 78
# 401 Unauthorized
# Not authorized.
# get rid of api number 78
# using api number 31
# 401 Unauthorized
# Not authorized.
# get rid of api number 31
# finished extracting tweets of everyone in 0.0030526293558333843 hours
#
# working on hashtag UkraineWar
#
# found 21 apis from juans stuff
# 21 api work
# Creating api objects for 45 API keys
# found 45 apis from apikeys.txt
# 29 api work
# Creating api objects for 83 API keys
# found 83 apis from apikeys2.txt
# 75 api work
# total working api is 125
# found unique users of this set
# pulled data on 2258 users
# already have feeds of 2258 users
# ['1733162454', '753546059700441089', '1320851616451485698', '1512434869317644290', '1165481895137816581', '25987846', '1399733521850195970', '1513246234026385412', '1498584208356352002', '1968120415', '1363484279804747776', '1510720868770529288', '2652298388', '1554353248500387840', '22349112', '1248351940301422593', '412451869', '261109532', '1547052955978825733', '1539912115699343360', '1550720506256658432', '1499333989303308288', '1493672363791040514', '1539008279258570752', '253405600', '1338622721060610055', '128982102', '2500378756', '776061085065547776', '1531316042894413824', '1524723918539419648', '1414905424298528775', '2854849324', '1421168385698770944', '1211405119788441600', '1492517180415651844', '1498246759058923527', '323748335', '176402547', '1218088655606165510', '1288981356014374912', '15641725', '1544758991712145410', '132974394', '1499725058792734722', '853535355504664576', '83825802', '38422776', '242780839', '1296751962147389442', '1462643185197355008', '397563985', '3064730787', '2368760118', '106479222', '1460866091064958978', '1435680839409491969', '954419876638150656', '1547469757099773952', '1449787838615199745', '1421444035642855424', '1029970214', '550319192', '986154398324854784', '1499402102665539585']
# now getting feeds of remaining 65 users
# Getting the feeds for each unique user in the hashtag UkraineWar
# begin timing...
#
# using api number 110
# 401 Unauthorized
# Not authorized.
# get rid of api number 110
# using api number 25
# 401 Unauthorized
# Not authorized.
# get rid of api number 25
# using api number 10
# 401 Unauthorized
# Not authorized.
# get rid of api number 10
# using api number 39
# 401 Unauthorized
# Not authorized.
# get rid of api number 39
# using api number 114
# 401 Unauthorized
# Not authorized.
# get rid of api number 114
# using api number 82
# 401 Unauthorized
# Not authorized.
# get rid of api number 82
# using api number 9
# 401 Unauthorized
# Not authorized.
# get rid of api number 9
# using api number 7
# 401 Unauthorized
# Not authorized.
# get rid of api number 7
# using api number 26
# 401 Unauthorized
# Not authorized.
# get rid of api number 26
# using api number 49
# 401 Unauthorized
# Not authorized.
# get rid of api number 49
# using api number 91
# 401 Unauthorized
# Not authorized.
# get rid of api number 91
# using api number 105
# 401 Unauthorized
# Not authorized.
# get rid of api number 105
# using api number 94
# 401 Unauthorized
# Not authorized.
# get rid of api number 94
# using api number 64
# 401 Unauthorized
# Not authorized.
# get rid of api number 64
# using api number 58
# 401 Unauthorized
# Not authorized.
# get rid of api number 58
# using api number 97
# 401 Unauthorized
# Not authorized.
# get rid of api number 97
# using api number 76
# 401 Unauthorized
# Not authorized.
# get rid of api number 76
# using api number 24
# 401 Unauthorized
# Not authorized.
# get rid of api number 24
# using api number 57
# 401 Unauthorized
# Not authorized.
# get rid of api number 57
# using api number 47
# 401 Unauthorized
# Not authorized.
# get rid of api number 47
# using api number 96
# 401 Unauthorized
# Not authorized.
# get rid of api number 96
# using api number 30
# 401 Unauthorized
# Not authorized.
# get rid of api number 30
# using api number 72
# 401 Unauthorized
# Not authorized.
# get rid of api number 72
# using api number 83
# 401 Unauthorized
# Not authorized.
# get rid of api number 83
# using api number 80
# 401 Unauthorized
# Not authorized.
# get rid of api number 80
# using api number 98
# 401 Unauthorized
# Not authorized.
# get rid of api number 98
# using api number 90
# 401 Unauthorized
# Not authorized.
# get rid of api number 90
# using api number 82
# 401 Unauthorized
# Not authorized.
# get rid of api number 82
# using api number 10
# 401 Unauthorized
# Not authorized.
# get rid of api number 10
# using api number 54
# 401 Unauthorized
# Not authorized.
# get rid of api number 54
# using api number 73
# 401 Unauthorized
# Not authorized.
# get rid of api number 73
# using api number 51
# 401 Unauthorized
# Not authorized.
# get rid of api number 51
# using api number 34
# {'2854849324': [{'id': '1563532840184123392', 'tweet-text': '"And like that he\'s gone." 🙂 🇺🇦 https://t.co/es9xfQgnF1', 'created_at': 'Sat Aug 27 14:24:12 +0000 2022', 'retweet_count': 0, 'favourite_count': 0}, {'id': '1563529728450891777', 'tweet-text': '@rphurley1 @Cincus @maria_drutska It makes them uncomfortable to be here. I know one and he spends less and less ti… https://t.co/MbdWRBn0BR', 'created_at': 'Sat Aug 27 14:11:50 +0000 2022', 'retweet_count': 0, 'favourite_count': 0}, {'id': '1563527999378849793', 'tweet-text': "@rphurley1 @Cincus @maria_drutska Aren't we driving any Trump supporters for Ukraine away with a statement such as that?", 'created_at': 'Sat Aug 27 14:04:58 +0000 2022', 'retweet_count': 0, 'favourite_count': 0}, {'id': '1563525813512704001', 'tweet-text': 'RT @Cincus: @maria_drutska That is why we still have a war: they don’t feel it. They don’t care. Stop tourist visas and oil and Putin himse…', 'created_at': 'Sat Aug 27 13:56:17 +0000 2022', 'retweet_count': 2, 'favourite_count': 0}, {'id': '1563525713487339520', 'tweet-text': 'RT @maria_drutska: I vote eternal visa ban for regular russians. If not, at least for her &amp; everyone else from moscow &amp; st. petersburg so t…', 'created_at': 'Sat Aug 27 13:55:53 +0000 2022', 'retweet_count': 95, 'favourite_count': 0}, {'id': '1563525398448594944', 'tweet-text': '@maria_drutska I thought she was just some unprepared young lady being ambushed with questions in the street.\n\nThen… https://t.co/MZteuOvdwG', 'created_at': 'Sat Aug 27 13:54:38 +0000 2022', 'retweet_count': 0, 'favourite_count': 0}, {'id': '1563522264762843139', 'tweet-text': 'RT @TheRealJ4GU4R: @DefenceU I have a dream too, to see those flying in Ukrainian airspace', 'created_at': 'Sat Aug 27 13:42:11 +0000 2022', 'retweet_count': 4, 'favourite_count': 0}, {'id': '1563522188426108929', 'tweet-text': 'RT @DefenceU: I have a dream.\n\nF-16\nF-22\nF-35\nEurofighter Typhoon\nMirage 2000\nGripen\n…\n… to protect the sky of civilization.\n📸 libkos https…', 'created_at': 'Sat Aug 27 13:41:53 +0000 2022', 'retweet_count': 2074, 'favourite_count': 0}, {'id': '1563521716684754950', 'tweet-text': "RT @RobinHoodKnave: Alright everyone, please donate $20, $50, $100, $300 whatever you can to the UkraineAidOps night vision fundraiser.\n\nI'…", 'created_at': 'Sat Aug 27 13:40:00 +0000 2022', 'retweet_count': 2, 'favourite_count': 0}, {'id': '1563521701161627650', 'tweet-text': 'Alright everyone, please donate $20, $50, $100, $300 whatever you can to the UkraineAidOps night vision fundraiser.… https://t.co/93mgeTcSDM', 'created_at': 'Sat Aug 27 13:39:57 +0000 2022', 'retweet_count': 2, 'favourite_count': 3}, {'id': '1563519124361187330', 'tweet-text': 'RT @Flash43191300: We saw their work in Lysychansk, in the direction of Popasna - Bakhmut. These are forward detachments operating in the f…', 'created_at': 'Sat Aug 27 13:29:42 +0000 2022', 'retweet_count': 15, 'favourite_count': 0}, {'id': '1563519100881473537', 'tweet-text': 'RT @Flash43191300: "According to our estimates, there are approximately 4.5-5 thousand of them. Today they work in certain areas, in the fi…', 'created_at': 'Sat Aug 27 13:29:37 +0000 2022', 'retweet_count': 14, 'favourite_count': 0}, {'id': '1563519069131018250', 'tweet-text': 'RT @Flash43191300: ⚡️ About 5,000 mercenaries of the Russian private military company \'Wagner" are taking part in the war against Ukraine,…', 'created_at': 'Sat Aug 27 13:29:29 +0000 2022', 'retweet_count': 50, 'favourite_count': 0}, {'id': '1563516296515715073', 'tweet-text': 'RT @Flash43191300: ⚡️The West must supply Ukraine with enough weapons to push the Russians back into position on February 23.\n\n“Ukrainians…', 'created_at': 'Sat Aug 27 13:18:28 +0000 2022', 'retweet_count': 226, 'favourite_count': 0}, {'id': '1563514748679131137', 'tweet-text': 'RT @benjit14: @RobinHoodKnave @general_ben Pulling hair out since April, when US policy in Ukraine became apparent. F16s launching JASSMs s…', 'created_at' ...
# using api number 64
# 401 Unauthorized
# Not authorized.
# get rid of api number 64
# using api number 13
# 401 Unauthorized
# Not authorized.
# get rid of api number 13
# using api number 63
# 401 Unauthorized
# Not authorized.
# get rid of api number 63
# using api number 34
# 401 Unauthorized
# Not authorized.
# get rid of api number 34
# using api number 68
# 401 Unauthorized
# Not authorized.
# get rid of api number 68
# using api number 6
# 401 Unauthorized
# Not authorized.
# get rid of api number 6
# using api number 66
# 401 Unauthorized
# Not authorized.
# get rid of api number 66
# using api number 11
# 401 Unauthorized
# Not authorized.
# get rid of api number 11
# using api number 6
# 401 Unauthorized
# Not authorized.
# get rid of api number 6
# using api number 72
# 401 Unauthorized
# Not authorized.
# get rid of api number 72
# using api number 7
# 401 Unauthorized
# Not authorized.
# get rid of api number 7
# using api number 29
# 401 Unauthorized
# Not authorized.
# get rid of api number 29
# using api number 7
# 401 Unauthorized
# Not authorized.
# get rid of api number 7
# using api number 61
# 401 Unauthorized
# Not authorized.
# get rid of api number 61
# using api number 33
# 401 Unauthorized
# Not authorized.
# get rid of api number 33
# using api number 72
# 401 Unauthorized
# Not authorized.
# get rid of api number 72
# using api number 57
# 401 Unauthorized
# Not authorized.
# get rid of api number 57
# using api number 9
# 401 Unauthorized
# Not authorized.
# get rid of api number 9
# using api number 28
# 401 Unauthorized
# Not authorized.
# get rid of api number 28
# using api number 35
# 401 Unauthorized
# Not authorized.
# get rid of api number 35
# using api number 0
# 401 Unauthorized
# Not authorized.
# get rid of api number 0
# using api number 21
# 401 Unauthorized
# Not authorized.
# get rid of api number 21
# using api number 11
# 401 Unauthorized
# Not authorized.
# get rid of api number 11
# using api number 52
# 401 Unauthorized
# Not authorized.
# get rid of api number 52
# using api number 8
# 401 Unauthorized
# Not authorized.
# get rid of api number 8
# using api number 14
# 401 Unauthorized
# Not authorized.
# get rid of api number 14
# using api number 63
# 401 Unauthorized
# Not authorized.
# get rid of api number 63
# using api number 28
# 401 Unauthorized
# Not authorized.
# get rid of api number 28
# using api number 31
# 401 Unauthorized
# Not authorized.
# get rid of api number 31
# using api number 22
# 401 Unauthorized
# Not authorized.
# get rid of api number 22
# using api number 14
# 401 Unauthorized
# Not authorized.
# get rid of api number 14
# using api number 23
# 401 Unauthorized
# Not authorized.
# get rid of api number 23
# finished extracting tweets of everyone in 0.004487245851944661 hours
