# %% [markdown]
# # IMPORT PACKAGES

# %%
from google.colab import drive
drive.mount('/content/drive')

# %cd /content/drive/My Drive/MSc_project/.MAIN
# Out:
# Mounted at /content/drive
# /content/drive/My Drive/MSc_project/.MAIN

# %%
import pandas as pd 
import pickle
import json
import os
import os.path
import numpy as np
import seaborn as sns
from collections import defaultdict
import joblib
import matplotlib.pyplot as plt
from matplotlib.ticker import (
                               FormatStrFormatter, 
                               AutoMinorLocator,
                               FuncFormatter,
                               )
import matplotlib.dates as mdates
from matplotlib.dates import DateFormatter
# %matplotlib inline
from scipy.spatial import distance
import math

from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score


import os
# os.chdir('G:\My Drive\MSc_project\.MAIN')

# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import numpy as np 
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, roc_curve, roc_auc_score, f1_score, precision_recall_curve
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV, train_test_split
import itertools

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.show()

def show_data(cm, print_res = 0):
    tp = cm[1,1]
    fn = cm[1,0]
    fp = cm[0,1]
    tn = cm[0,0]
    if print_res == 1:
        print('Precision =     {:.3f}'.format(tp/(tp+fp)))
        print('Recall (TPR) =  {:.3f}'.format(tp/(tp+fn)))
        print('Fallout (FPR) = {:.3e}'.format(fp/(fp+tn)))
        print('F1 score = {:.3e}'.format(tp/(tp + 0.5*(fp+fn))))
    return tp/(tp+fp), tp/(tp+fn), fp/(fp+tn)

# %% [markdown]
# # USER + TWEET FEATURES

# %%
hashtags = ['avengers','blm','brexit','climatechange','covid','gaza','loveisland','monkeypox','nhs','olivianewtonjohn','supercup','UkraineWar']

for h_i,hashtag in enumerate(hashtags):

    print('--------------\n--------------')
    print(f'Considering {hashtag}')

    df = pd.read_csv(f'multisource_analysis/user_ft_data/{hashtag}_scored_tweets2.csv')
    df.drop(['Unnamed: 0','hashtag','user_id','text_len','text_word_count'], inplace = True, axis =1)
    # df.drop(['Unnamed: 0','hashtag','user_id','target'], inplace = True, axis =1)

    fector_df = df.copy()[df['is-infector']==1]
    fector_df.set_index('target',inplace=True)
    targ_df = df.copy()[df['is-target']==1]
    targ_df.set_index('target',inplace=True)
    t_cols = df.columns.tolist()
    t_cols = [x for x in t_cols if 'user' not in x]
    t_cols = [x for x in t_cols if x not in ['is-target','is-infector','is-informer','num_male','num_female','text','target'] ]

    u_cols = df.columns.tolist()
    u_cols = [ x for x in u_cols if 'user' in x] 
    u_cols = u_cols + ['num_male','num_female']
    u_cols = [x for x in u_cols if 'count' not in x]

    cols = u_cols+t_cols

    infector_df = pd.concat( [targ_df.copy()[t_cols],fector_df.copy()[u_cols] ], axis=1   )
    infector_df = infector_df.copy().sample(frac=1)


    informer_df = df[df['is-informer']==1][cols]
    informer_df = informer_df.copy().sample(frac=1)

    infector_df['label'] = [1]*len(infector_df)
    informer_df['label'] = [0]*len(informer_df)

    n1 = int(len(infector_df)*0.7)
    n2 = int(len(informer_df)*0.7)

    data = pd.concat( [ infector_df.copy().iloc[0:n1], informer_df.copy().iloc[0:n2] ], axis =0)
    data = data.sample(frac=1)

    data['sentiment'].replace('neutral', 0, inplace = True)
    data['sentiment'].replace('negative', 1, inplace = True)
    data['sentiment'].replace('positive', 2, inplace = True)
    data['user_sentiment_mode'].replace('neutral', 0, inplace = True)
    data['user_sentiment_mode'].replace('negative', 1, inplace = True)
    data['user_sentiment_mode'].replace('positive', 2, inplace = True)

    ### TESTING SET

    holdout_data = pd.concat( [ infector_df.copy().iloc[n1:],informer_df.copy().iloc[n2:] ], axis =0)
    holdout_data = holdout_data.sample(frac=1)

    holdout_data['sentiment'].replace('neutral', 0, inplace = True)
    holdout_data['sentiment'].replace('negative', 1, inplace = True)
    holdout_data['sentiment'].replace('positive', 2, inplace = True)
    holdout_data['user_sentiment_mode'].replace('neutral', 0, inplace = True)
    holdout_data['user_sentiment_mode'].replace('negative', 1, inplace = True)
    holdout_data['user_sentiment_mode'].replace('positive', 2, inplace = True)

    print('length of data')
    print((len(data)+len(holdout_data)))

    X = data[cols]
    labels = data['label'].tolist()

    num_fector = len( data[data['label']==1] )
    num_informer = len( data[data['label']==0] )

    print(f'Num of Infectors in Training: { num_fector } ')
    print(f'Num of informers in Training: { num_informer } ')

    X_train, X_test, y_train, y_test = train_test_split(X, labels, test_size=0.1, random_state=2,shuffle=True)

    # model = XGBClassifier(use_label_encoder=False, eval_metric='mlogloss')
    # {'learning_rate': 0.3, 'n_estimators': 100, 'objective': 'binary:logistic', 'max_depth': 6, 'min_child_weight': 1, 'max_delta_step': 0, 'subsample': 0.8}

    model = XGBClassifier(use_label_encoder=False, learning_rate=0.3, n_estimators =  100, objective = 'binary:logistic', max_depth = 6, min_child_weight = 1, max_delta_step = 0, subsample = 0.8)

    model.fit(X_train, y_train)

    y_pred = model.predict(X_test)

    accuracy = accuracy_score(y_test, y_pred)

    import xgboost as xgb
    xgb.plot_importance(model, max_num_features=20)
    plt.figure(figsize = (40, 70))
    # plt.savefig('diss_figs/historic_tweet_featurs.png', facecolor='w')
    plt.show()


    X_test = holdout_data[cols]
    y_test = holdout_data['label']

    y_pred = model.predict(X_test)
    thresh = 0.08
    y_pred [y_pred > thresh] = 1
    y_pred [y_pred <= thresh] = 0
    cm = confusion_matrix(y_test, y_pred)
    plot_confusion_matrix(cm, ['0', '1'], )
    pr, tpr, fpr = show_data(cm, print_res = 1);

    del data
    del holdout_data
    del df
    del model
    del y_test
    del y_pred

    print(f'FINISHED PREDICTION FOR {hashtag}\n\n\n')
# Out:
# --------------
# --------------
# Considering avengers
# length of training set 6454
# length of testing set 2768
# Num of Infectors in Training: 941
# Num of informers in Training: 5513
# training accuracy
# 0.9705882352941176
# Precision =     0.956
# Recall (TPR) =  0.908
# Fallout (FPR) = 7.191e-03
# F1 score = 9.315e-01
# FINISHED PREDICTION FOR avengers
#
#
#
# --------------
# --------------
# Considering blm
# length of training set 10930
# length of testing set 4686
# Num of Infectors in Training: 1491
# Num of informers in Training: 9439
# training accuracy
# 0.9743824336688015
# Precision =     0.888
# Recall (TPR) =  0.881
# Fallout (FPR) = 1.755e-02
# F1 score = 8.847e-01
# FINISHED PREDICTION FOR blm
#
#
#
# --------------
# --------------
# Considering brexit
# length of training set 12559
# length of testing set 5384
# Num of Infectors in Training: 1390
# Num of informers in Training: 11169
# training accuracy
# 0.9896496815286624
# Precision =     0.987
# Recall (TPR) =  0.889
# Fallout (FPR) = 1.462e-03
# F1 score = 9.357e-01
# FINISHED PREDICTION FOR brexit
#
#
#
# --------------
# --------------
# Considering climatechange
# length of training set 7659
# length of testing set 3284
# Num of Infectors in Training: 1099
# Num of informers in Training: 6560
# training accuracy
# 0.9686684073107049
# Precision =     0.937
# Recall (TPR) =  0.824
# Fallout (FPR) = 9.246e-03
# F1 score = 8.771e-01
# FINISHED PREDICTION FOR climatechange
#
#
#
# --------------
# --------------
# Considering covid
# length of training set 7406
# length of testing set 3176
# Num of Infectors in Training: 1094
# Num of informers in Training: 6312
# training accuracy
# 0.9784075573549258
# Precision =     0.954
# Recall (TPR) =  0.791
# Fallout (FPR) = 6.652e-03
# F1 score = 8.651e-01
# FINISHED PREDICTION FOR covid
#
#
#
# --------------
# --------------
# Considering gaza
# length of training set 6968
# length of testing set 2988
# Num of Infectors in Training: 1012
# Num of informers in Training: 5956
# training accuracy
# 0.9827833572453372
# Precision =     0.975
# Recall (TPR) =  0.890
# Fallout (FPR) = 3.917e-03
# F1 score = 9.303e-01
# FINISHED PREDICTION FOR gaza
#
#
#
# --------------
# --------------
# Considering loveisland
# length of training set 6948
# length of testing set 2979
# Num of Infectors in Training: 1025
# Num of informers in Training: 5923
# training accuracy
# 0.9928057553956835
# Precision =     0.988
# Recall (TPR) =  0.905
# Fallout (FPR) = 1.969e-03
# F1 score = 9.442e-01
# FINISHED PREDICTION FOR loveisland
#
#
#
# --------------
# --------------
# Considering monkeypox
# length of training set 7995
# length of testing set 3427
# Num of Infectors in Training: 1171
# Num of informers in Training: 6824
# training accuracy
# 0.96625
# Precision =     0.954
# Recall (TPR) =  0.821
# Fallout (FPR) = 6.838e-03
# F1 score = 8.822e-01
# FINISHED PREDICTION FOR monkeypox
#
#
#
# --------------
# --------------
# Considering nhs
# length of training set 12968
# length of testing set 5559
# Num of Infectors in Training: 1630
# Num of informers in Training: 11338
# training accuracy
# 0.9776407093292213
# Precision =     0.970
# Recall (TPR) =  0.878
# Fallout (FPR) = 3.909e-03
# F1 score = 9.219e-01
# FINISHED PREDICTION FOR nhs
#
#
#
# --------------
# --------------
# Considering olivianewtonjohn
# length of training set 5665
# length of testing set 2430
# Num of Infectors in Training: 912
# Num of informers in Training: 4753
# training accuracy
# 0.9347442680776014
# Precision =     0.906
# Recall (TPR) =  0.691
# Fallout (FPR) = 1.374e-02
# F1 score = 7.844e-01
# FINISHED PREDICTION FOR olivianewtonjohn
#
#
#
# --------------
# --------------
# Considering supercup
# length of training set 6568
# length of testing set 2817
# Num of Infectors in Training: 1181
# Num of informers in Training: 5387
# training accuracy
# 0.9939117199391172
# Precision =     0.994
# Recall (TPR) =  0.964
# Fallout (FPR) = 1.299e-03
# F1 score = 9.790e-01
# FINISHED PREDICTION FOR supercup
#
#
#
# --------------
# --------------
# Considering UkraineWar
# length of training set 7627
# length of testing set 3270
# Num of Infectors in Training: 1110
# Num of informers in Training: 6517
# training accuracy
# 0.9882044560943644
# Precision =     0.981
# Recall (TPR) =  0.960
# Fallout (FPR) = 3.221e-03
# F1 score = 9.703e-01
# FINISHED PREDICTION FOR UkraineWar

# %% [markdown]
# # 10 FEED USERS + TWEETS

# %%
hashtags = ['avengers','blm','brexit','climatechange','covid','gaza','loveisland','monkeypox','nhs','olivianewtonjohn','supercup','UkraineWar']

for h_i,hashtag in enumerate(hashtags):

    print('--------------\n--------------')
    print(f'Considering {hashtag}')
    df = pd.read_csv(f'multisource_analysis/user_ft_data/{hashtag}_scored_tweets2.csv')
    df.drop(['Unnamed: 0','hashtag','user_id'], inplace = True, axis =1)
    # df.drop(['Unnamed: 0','hashtag','user_id','target'], inplace = True, axis =1)

    fector_df = df.copy()[df['is-infector']==1]
    fector_df.set_index('target',inplace=True)


    u_cols = df.columns.tolist()
    u_cols = [ x for x in u_cols if 'user' in x] 
    u_cols = u_cols + ['num_male','num_female']
    u_cols = [x for x in u_cols if 'count' not in x]

    cols = u_cols

    infector_df = fector_df.copy()[cols]
    infector_df = infector_df.copy().sample(frac=1)

    informer_df = df[df['is-informer']==1][cols]
    informer_df = informer_df.copy().sample(frac=1)

    infector_df['label'] = [1]*len(infector_df)
    informer_df['label'] = [0]*len(informer_df)

    n1 = int(len(infector_df)*0.7)
    n2 = int(len(informer_df)*0.7)

    data = pd.concat( [ infector_df.copy().iloc[0:n1], informer_df.copy().iloc[0:n2] ], axis =0)
    data = data.sample(frac=1)

    data['user_sentiment_mode'].replace('neutral', 0, inplace = True)
    data['user_sentiment_mode'].replace('negative', 1, inplace = True)
    data['user_sentiment_mode'].replace('positive', 2, inplace = True)

    ### TESTING SET

    holdout_data = pd.concat( [ infector_df.copy().iloc[n1:],informer_df.copy().iloc[n2:] ], axis =0)
    holdout_data = holdout_data.sample(frac=1)

    holdout_data['user_sentiment_mode'].replace('neutral', 0, inplace = True)
    holdout_data['user_sentiment_mode'].replace('negative', 1, inplace = True)
    holdout_data['user_sentiment_mode'].replace('positive', 2, inplace = True)

    print('length of data')
    print((len(data)+len(holdout_data)))

    X = data[cols]
    labels = data['label'].tolist()

    num_fector = len( data[data['label']==1] )
    num_informer = len( data[data['label']==0] )

    print(f'Num of Infectors in Training: { num_fector } ')
    print(f'Num of informers in Training: { num_informer } ')

    X_train, X_test, y_train, y_test = train_test_split(X, labels, test_size=0.1, random_state=2,shuffle=True)

    # model = XGBClassifier(use_label_encoder=False, eval_metric='mlogloss')
    # {'learning_rate': 0.3, 'n_estimators': 100, 'objective': 'binary:logistic', 'max_depth': 6, 'min_child_weight': 1, 'max_delta_step': 0, 'subsample': 0.8}

    model = XGBClassifier(use_label_encoder=False, learning_rate=0.3, n_estimators =  100, objective = 'binary:logistic', max_depth = 6, min_child_weight = 1, max_delta_step = 0, subsample = 0.8)

    model.fit(X_train, y_train)

    y_pred = model.predict(X_test)

    accuracy = accuracy_score(y_test, y_pred)

    import xgboost as xgb
    xgb.plot_importance(model, max_num_features=20)
    plt.figure(figsize = (40, 70))
    # plt.savefig('diss_figs/historic_tweet_featurs.png', facecolor='w')
    plt.show()


    X_test = holdout_data[cols]
    y_test = holdout_data['label']

    y_pred = model.predict(X_test)
    thresh = 0.08
    y_pred [y_pred > thresh] = 1
    y_pred [y_pred <= thresh] = 0
    cm = confusion_matrix(y_test, y_pred)
    plot_confusion_matrix(cm, ['0', '1'], )
    pr, tpr, fpr = show_data(cm, print_res = 1);

    del data
    del holdout_data
    del df
    del model
    del y_pred
    del y_test

    print(f'FINISHED PREDICTION FOR {hashtag}\n\n\n')
# Out:
# --------------
# --------------
# Considering avengers
# length of data
# 9222
# Num of Infectors in Training: 941
# Num of informers in Training: 5513
# Precision =     0.433
# Recall (TPR) =  0.200
# Fallout (FPR) = 4.484e-02
# F1 score = 2.741e-01
# FINISHED PREDICTION FOR avengers
#
#
#
# --------------
# --------------
# Considering blm
# length of data
# 15616
# Num of Infectors in Training: 1491
# Num of informers in Training: 9439
# Precision =     0.545
# Recall (TPR) =  0.761
# Fallout (FPR) = 1.003e-01
# F1 score = 6.354e-01
# FINISHED PREDICTION FOR blm
#
#
#
# --------------
# --------------
# Considering brexit
# length of data
# 17943
# Num of Infectors in Training: 1390
# Num of informers in Training: 11169
# Precision =     0.605
# Recall (TPR) =  0.631
# Fallout (FPR) = 5.139e-02
# F1 score = 6.180e-01
# FINISHED PREDICTION FOR brexit
#
#
#
# --------------
# --------------
# Considering climatechange
# length of data
# 10943
# Num of Infectors in Training: 1099
# Num of informers in Training: 6560
# Precision =     0.429
# Recall (TPR) =  0.148
# Fallout (FPR) = 3.307e-02
# F1 score = 2.205e-01
# FINISHED PREDICTION FOR climatechange
#
#
#
# --------------
# --------------
# Considering covid
# length of data
# 10582
# Num of Infectors in Training: 1094
# Num of informers in Training: 6312
# Precision =     0.493
# Recall (TPR) =  0.232
# Fallout (FPR) = 4.139e-02
# F1 score = 3.155e-01
# FINISHED PREDICTION FOR covid
#
#
#
# --------------
# --------------
# Considering gaza
# length of data
# 9956
# Num of Infectors in Training: 1012
# Num of informers in Training: 5956
# Precision =     0.799
# Recall (TPR) =  0.375
# Fallout (FPR) = 1.606e-02
# F1 score = 5.102e-01
# FINISHED PREDICTION FOR gaza
#
#
#
# --------------
# --------------
# Considering loveisland
# length of data
# 9927
# Num of Infectors in Training: 1025
# Num of informers in Training: 5923
# Precision =     0.723
# Recall (TPR) =  0.136
# Fallout (FPR) = 9.059e-03
# F1 score = 2.294e-01
# FINISHED PREDICTION FOR loveisland
#
#
#
# --------------
# --------------
# Considering monkeypox
# length of data
# 11422
# Num of Infectors in Training: 1171
# Num of informers in Training: 6824
# Precision =     0.537
# Recall (TPR) =  0.245
# Fallout (FPR) = 3.624e-02
# F1 score = 3.365e-01
# FINISHED PREDICTION FOR monkeypox
#
#
#
# --------------
# --------------
# Considering nhs
# length of data
# 18527
# Num of Infectors in Training: 1630
# Num of informers in Training: 11338
# Precision =     0.601
# Recall (TPR) =  0.548
# Fallout (FPR) = 5.226e-02
# F1 score = 5.734e-01
# FINISHED PREDICTION FOR nhs
#
#
#
# --------------
# --------------
# Considering olivianewtonjohn
# length of data
# 8095
# Num of Infectors in Training: 912
# Num of informers in Training: 4753
# Precision =     0.500
# Recall (TPR) =  0.194
# Fallout (FPR) = 3.729e-02
# F1 score = 2.794e-01
# FINISHED PREDICTION FOR olivianewtonjohn
#
#
#
# --------------
# --------------
# Considering supercup
# length of data
# 9385
# Num of Infectors in Training: 1181
# Num of informers in Training: 5387
# Precision =     0.628
# Recall (TPR) =  0.357
# Fallout (FPR) = 4.632e-02
# F1 score = 4.553e-01
# FINISHED PREDICTION FOR supercup
#
#
#
# --------------
# --------------
# Considering UkraineWar
# length of data
# 10897
# Num of Infectors in Training: 1110
# Num of informers in Training: 6517
# Precision =     0.572
# Recall (TPR) =  0.508
# Fallout (FPR) = 6.478e-02
# F1 score = 5.384e-01
# FINISHED PREDICTION FOR UkraineWar

# %% [markdown]
# # TWEET PREDICTION

# %%
hashtags = ['avengers','blm','brexit','climatechange','covid','gaza','loveisland','monkeypox','nhs','olivianewtonjohn','supercup','UkraineWar']

for h_i,hashtag in enumerate(hashtags):

    print('--------------\n--------------')
    print(f'Considering {hashtag}')
    df = pd.read_csv(f'multisource_analysis/data/{hashtag}_scored_tweets.csv')
    df.drop(['Unnamed: 0','hashtag','user_id','gender','text_word_count','text_len'], inplace = True, axis =1)
    # df.drop(['Unnamed: 0','hashtag','user_id','target'], inplace = True, axis =1)

    fector_df = df.copy()[df['is-infector']==1]
    fector_df.set_index('target',inplace=True)
    targ_df = df.copy()[df['is-target']==1]
    targ_df.set_index('target',inplace=True)
    t_cols = df.columns.tolist()
    t_cols = [x for x in t_cols if 'user' not in x]
    t_cols = [x for x in t_cols if x not in ['is-target','is-infector','is-informer','num_male','num_female','text','target'] ]

    cols = t_cols

    infector_df = targ_df.copy()[cols]
    infector_df = infector_df.copy().sample(frac=1)

    informer_df = df.copy()[df['is-informer']==1][cols]
    informer_df = informer_df.copy().sample(frac=1)

    infector_df['label'] = [1]*len(infector_df)
    informer_df['label'] = [0]*len(informer_df)

    n1 = int(len(infector_df)*0.8)
    n2 = int(len(informer_df)*0.8)

    data = pd.concat( [ infector_df.copy().iloc[0:n1], informer_df.copy().iloc[0:n2] ], axis =0)
    data = data.sample(frac=1)

    data['sentiment'].replace('neutral', 0, inplace = True)
    data['sentiment'].replace('negative', 1, inplace = True)
    data['sentiment'].replace('positive', 2, inplace = True)

    ### TESTING SET

    holdout_data = pd.concat( [ infector_df.copy().iloc[n1:],informer_df.copy().iloc[n2:] ], axis =0)
    holdout_data = holdout_data.sample(frac=1)

    holdout_data['sentiment'].replace('neutral', 0, inplace = True)
    holdout_data['sentiment'].replace('negative', 1, inplace = True)
    holdout_data['sentiment'].replace('positive', 2, inplace = True)

    print('length of data')
    print((len(data)+len(holdout_data)))

    X = data[cols]
    labels = data['label'].tolist()

    X_train, X_test, y_train, y_test = train_test_split(X, labels, test_size=0.1, random_state=2,shuffle=True)

    # model = XGBClassifier(use_label_encoder=False, eval_metric='mlogloss')
    # {'learning_rate': 0.3, 'n_estimators': 100, 'objective': 'binary:logistic', 'max_depth': 6, 'min_child_weight': 1, 'max_delta_step': 0, 'subsample': 0.8}

    model = XGBClassifier(use_label_encoder=False, learning_rate=0.3, n_estimators =  100, objective = 'binary:logistic', max_depth = 6, min_child_weight = 1, max_delta_step = 0, subsample = 0.8)

    model.fit(X_train, y_train)

    y_pred = model.predict(X_test)

    accuracy = accuracy_score(y_test, y_pred)

    import xgboost as xgb
    xgb.plot_importance(model, max_num_features=20)
    plt.figure(figsize = (40, 70))
    # plt.savefig('diss_figs/historic_tweet_featurs.png', facecolor='w')
    plt.show()


    X_test = holdout_data[cols]
    y_test = holdout_data['label']

    y_pred = model.predict(X_test)
    thresh = 0.08
    y_pred [y_pred > thresh] = 1
    y_pred [y_pred <= thresh] = 0
    cm = confusion_matrix(y_test, y_pred)
    plot_confusion_matrix(cm, ['0', '1'], )
    pr, tpr, fpr = show_data(cm, print_res = 1);

    del data
    del holdout_data
    del df
    del model
    del y_pred
    del y_test

    print(f'FINISHED PREDICTION FOR {hashtag}\n\n\n')
# Out:
# --------------
# --------------
# Considering avengers
# length of data
# 9681
# Precision =     0.713
# Recall (TPR) =  0.300
# Fallout (FPR) = 1.983e-02
# F1 score = 4.227e-01
# FINISHED PREDICTION FOR avengers
#
#
#
# --------------
# --------------
# Considering blm
# length of data
# 29217
# Precision =     0.463
# Recall (TPR) =  0.057
# Fallout (FPR) = 1.006e-02
# F1 score = 1.014e-01
# FINISHED PREDICTION FOR blm
#
#
#
# --------------
# --------------
# Considering brexit
# length of data
# 33520
# Precision =     0.524
# Recall (TPR) =  0.049
# Fallout (FPR) = 4.976e-03
# F1 score = 8.931e-02
# FINISHED PREDICTION FOR brexit
#
#
#
# --------------
# --------------
# Considering climatechange
# length of data
# 14190
# Precision =     0.520
# Recall (TPR) =  0.235
# Fallout (FPR) = 3.427e-02
# F1 score = 3.233e-01
# FINISHED PREDICTION FOR climatechange
#
#
#
# --------------
# --------------
# Considering covid
# length of data
# 12968
# Precision =     0.563
# Recall (TPR) =  0.183
# Fallout (FPR) = 2.334e-02
# F1 score = 2.757e-01
# FINISHED PREDICTION FOR covid
#
#
#
# --------------
# --------------
# Considering gaza
# length of data
# 10927
# Precision =     0.642
# Recall (TPR) =  0.341
# Fallout (FPR) = 3.147e-02
# F1 score = 4.454e-01
# FINISHED PREDICTION FOR gaza
#
#
#
# --------------
# --------------
# Considering loveisland
# length of data
# 10409
# Precision =     0.751
# Recall (TPR) =  0.456
# Fallout (FPR) = 2.522e-02
# F1 score = 5.678e-01
# FINISHED PREDICTION FOR loveisland
#
#
#
# --------------
# --------------
# Considering monkeypox
# length of data
# 32361
# Precision =     0.502
# Recall (TPR) =  0.289
# Fallout (FPR) = 4.156e-02
# F1 score = 3.672e-01
# FINISHED PREDICTION FOR monkeypox
#
#
#
# --------------
# --------------
# Considering nhs
# length of data
# 51792
# Precision =     0.401
# Recall (TPR) =  0.053
# Fallout (FPR) = 9.521e-03
# F1 score = 9.343e-02
# FINISHED PREDICTION FOR nhs
#
#
#
# --------------
# --------------
# Considering olivianewtonjohn
# length of data
# 8443
# Precision =     0.507
# Recall (TPR) =  0.259
# Fallout (FPR) = 4.705e-02
# F1 score = 3.433e-01
# FINISHED PREDICTION FOR olivianewtonjohn
#
#
#
# --------------
# --------------
# Considering supercup
# length of data
# 19797
# Precision =     0.700
# Recall (TPR) =  0.451
# Fallout (FPR) = 3.990e-02
# F1 score = 5.481e-01
# FINISHED PREDICTION FOR supercup
#
#
#
# --------------
# --------------
# Considering UkraineWar
# length of data
# 18028
# Precision =     0.740
# Recall (TPR) =  0.256
# Fallout (FPR) = 1.449e-02
# F1 score = 3.804e-01
# FINISHED PREDICTION FOR UkraineWar

# %% [markdown]
# # USER FEATURES

# %%
hashtags = ['avengers','blm','brexit','climatechange','covid','gaza','loveisland','monkeypox','nhs','olivianewtonjohn','supercup','UkraineWar']

for h_i,hashtag in enumerate(hashtags):

    print('--------------\n--------------')
    print(f'Considering {hashtag}')
    df = pd.read_csv(f'multisource_analysis/user_ft_data/{hashtag}_scored_tweets2.csv')
    df.drop(['Unnamed: 0','hashtag','user_id'], inplace = True, axis =1)
    # df.drop(['Unnamed: 0','hashtag','user_id','target'], inplace = True, axis =1)

    fector_df = df.copy()[df['is-infector']==1]
    fector_df.set_index('target',inplace=True)


    u_cols = df.columns.tolist()
    u_cols = [ x for x in u_cols if 'user' in x] 
    u_cols = u_cols + ['num_male','num_female']
    u_cols = [x for x in u_cols if 'count' not in x]

    cols = u_cols

    infector_df = fector_df.copy()[cols]
    infector_df = infector_df.copy().sample(frac=1)

    informer_df = df[df['is-informer']==1][cols]
    informer_df = informer_df.copy().sample(frac=1)

    infector_df['label'] = [1]*len(infector_df)
    informer_df['label'] = [0]*len(informer_df)

    n1 = int(len(infector_df)*0.7)
    n2 = int(len(informer_df)*0.7)

    data = pd.concat( [ infector_df.copy().iloc[0:n1], informer_df.copy().iloc[0:n2] ], axis =0)
    data = data.sample(frac=1)

    data['user_sentiment_mode'].replace('neutral', 0, inplace = True)
    data['user_sentiment_mode'].replace('negative', 1, inplace = True)
    data['user_sentiment_mode'].replace('positive', 2, inplace = True)

    ### TESTING SET

    holdout_data = pd.concat( [ infector_df.copy().iloc[n1:],informer_df.copy().iloc[n2:] ], axis =0)
    holdout_data = holdout_data.sample(frac=1)

    holdout_data['user_sentiment_mode'].replace('neutral', 0, inplace = True)
    holdout_data['user_sentiment_mode'].replace('negative', 1, inplace = True)
    holdout_data['user_sentiment_mode'].replace('positive', 2, inplace = True)

    print('length of data')
    print((len(data)+len(holdout_data)))

    X = data[cols]
    labels = data['label'].tolist()

    num_fector = len( data[data['label']==1] )
    num_informer = len( data[data['label']==0] )

    print(f'Num of Infectors in Training: { num_fector } ')
    print(f'Num of informers in Training: { num_informer } ')

    X_train, X_test, y_train, y_test = train_test_split(X, labels, test_size=0.1, random_state=2,shuffle=True)

    # model = XGBClassifier(use_label_encoder=False, eval_metric='mlogloss')
    # {'learning_rate': 0.3, 'n_estimators': 100, 'objective': 'binary:logistic', 'max_depth': 6, 'min_child_weight': 1, 'max_delta_step': 0, 'subsample': 0.8}

    model = XGBClassifier(use_label_encoder=False, learning_rate=0.3, n_estimators =  100, objective = 'binary:logistic', max_depth = 6, min_child_weight = 1, max_delta_step = 0, subsample = 0.8)

    model.fit(X_train, y_train)

    y_pred = model.predict(X_test)

    accuracy = accuracy_score(y_test, y_pred)

    import xgboost as xgb
    xgb.plot_importance(model, max_num_features=20)
    plt.figure(figsize = (40, 70))
    # plt.savefig('diss_figs/historic_tweet_featurs.png', facecolor='w')
    plt.show()


    X_test = holdout_data[cols]
    y_test = holdout_data['label']

    y_pred = model.predict(X_test)
    thresh = 0.08
    y_pred [y_pred > thresh] = 1
    y_pred [y_pred <= thresh] = 0
    cm = confusion_matrix(y_test, y_pred)
    plot_confusion_matrix(cm, ['0', '1'], )
    pr, tpr, fpr = show_data(cm, print_res = 1);

    del data
    del holdout_data
    del df
    del model
    del y_pred
    del y_test

    print(f'FINISHED PREDICTION FOR {hashtag}\n\n\n')
# Out:
# --------------
# --------------
# Considering avengers
# length of data
# 9222
# Num of Infectors in Training: 941
# Num of informers in Training: 5513
# Precision =     0.433
# Recall (TPR) =  0.200
# Fallout (FPR) = 4.484e-02
# F1 score = 2.741e-01
# FINISHED PREDICTION FOR avengers
#
#
#
# --------------
# --------------
# Considering blm
# length of data
# 15616
# Num of Infectors in Training: 1491
# Num of informers in Training: 9439
# Precision =     0.545
# Recall (TPR) =  0.761
# Fallout (FPR) = 1.003e-01
# F1 score = 6.354e-01
# FINISHED PREDICTION FOR blm
#
#
#
# --------------
# --------------
# Considering brexit
# length of data
# 17943
# Num of Infectors in Training: 1390
# Num of informers in Training: 11169
# Precision =     0.605
# Recall (TPR) =  0.631
# Fallout (FPR) = 5.139e-02
# F1 score = 6.180e-01
# FINISHED PREDICTION FOR brexit
#
#
#
# --------------
# --------------
# Considering climatechange
# length of data
# 10943
# Num of Infectors in Training: 1099
# Num of informers in Training: 6560
# Precision =     0.429
# Recall (TPR) =  0.148
# Fallout (FPR) = 3.307e-02
# F1 score = 2.205e-01
# FINISHED PREDICTION FOR climatechange
#
#
#
# --------------
# --------------
# Considering covid
# length of data
# 10582
# Num of Infectors in Training: 1094
# Num of informers in Training: 6312
# Precision =     0.493
# Recall (TPR) =  0.232
# Fallout (FPR) = 4.139e-02
# F1 score = 3.155e-01
# FINISHED PREDICTION FOR covid
#
#
#
# --------------
# --------------
# Considering gaza
# length of data
# 9956
# Num of Infectors in Training: 1012
# Num of informers in Training: 5956
# Precision =     0.799
# Recall (TPR) =  0.375
# Fallout (FPR) = 1.606e-02
# F1 score = 5.102e-01
# FINISHED PREDICTION FOR gaza
#
#
#
# --------------
# --------------
# Considering loveisland
# length of data
# 9927
# Num of Infectors in Training: 1025
# Num of informers in Training: 5923
# Precision =     0.723
# Recall (TPR) =  0.136
# Fallout (FPR) = 9.059e-03
# F1 score = 2.294e-01
# FINISHED PREDICTION FOR loveisland
#
#
#
# --------------
# --------------
# Considering monkeypox
# length of data
# 11422
# Num of Infectors in Training: 1171
# Num of informers in Training: 6824
# Precision =     0.537
# Recall (TPR) =  0.245
# Fallout (FPR) = 3.624e-02
# F1 score = 3.365e-01
# FINISHED PREDICTION FOR monkeypox
#
#
#
# --------------
# --------------
# Considering nhs
# length of data
# 18527
# Num of Infectors in Training: 1630
# Num of informers in Training: 11338
# Precision =     0.601
# Recall (TPR) =  0.548
# Fallout (FPR) = 5.226e-02
# F1 score = 5.734e-01
# FINISHED PREDICTION FOR nhs
#
#
#
# --------------
# --------------
# Considering olivianewtonjohn
# length of data
# 8095
# Num of Infectors in Training: 912
# Num of informers in Training: 4753
# Precision =     0.500
# Recall (TPR) =  0.194
# Fallout (FPR) = 3.729e-02
# F1 score = 2.794e-01
# FINISHED PREDICTION FOR olivianewtonjohn
#
#
#
# --------------
# --------------
# Considering supercup
# length of data
# 9385
# Num of Infectors in Training: 1181
# Num of informers in Training: 5387
# Precision =     0.628
# Recall (TPR) =  0.357
# Fallout (FPR) = 4.632e-02
# F1 score = 4.553e-01
# FINISHED PREDICTION FOR supercup
#
#
#
# --------------
# --------------
# Considering UkraineWar
# length of data
# 10897
# Num of Infectors in Training: 1110
# Num of informers in Training: 6517
# Precision =     0.572
# Recall (TPR) =  0.508
# Fallout (FPR) = 6.478e-02
# F1 score = 5.384e-01
# FINISHED PREDICTION FOR UkraineWar
